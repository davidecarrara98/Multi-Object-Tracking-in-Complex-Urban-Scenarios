# %%
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm
from PIL import Image
import h5py
import os

# %%
f = h5py.File('..\..\Data\data_109.h5', 'r')
f.keys()
#f['Sequence'].keys()
f['Sequence']['0'].keys()
# Out:
# <KeysViewHDF5 ['Detections', 'Image', 'Points', 'Security', 'Tracks']>

# %%
world2cam_matrix = np.asarray(f['TMatrixWorldToCam'])
world2cam_matrix.shape
# Out:
# (4, 4)

# %%
proj_matrix = np.asarray(f['ProjectionMatrix'])
proj_matrix
# Out:
# array([[ 3.48025469e+02,  0.00000000e+00,  3.89720963e+02,
#          0.00000000e+00],
#        [ 0.00000000e+00,  3.98250028e+02,  2.91244594e+02,
#         -1.81898940e-12],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00]])

# %%
#Choose an instant
frame = f['Sequence']['730']

# %%
# Detections
np.asarray(frame['Detections'])
# Out:
# array([((10.15909738, -5.72488395, -1.10602823), 3.78564644, 0.37349591, 1.78490806, 1.49987257),
#        ((-6.73447514, 23.63771317, -1.13711529), 2.2411468 , 1.47715962, 1.45631874, 1.5422827 ),
#        ((-2.53191846, 29.16449062, -0.91711677), 1.67298651, 1.22097492, 1.91595078, 1.30960631)],
#       dtype=[('Pos', [('X', '<f8'), ('Y', '<f8'), ('Z', '<f8')]), ('Length', '<f8'), ('Width', '<f8'), ('Height', '<f8'), ('Angle', '<f8')])

# %%
# Tracks
np.asarray(frame['Tracks'])
# Out:
# array([(904, (-6.97081624, 23.64717533, -1.12694108), (-0.16250388,  0.98905336,  0.03343586), 18, 2),
#        (906, (10.12959563, -6.35163374, -1.22015665), ( 0.45653028, -4.1953461 , -0.07944497), 18, 2),
#        (909, (-2.50603034, 29.14999051, -0.90539246), ( 1.70950458,  6.24991193, -0.02661349),  0, 1)],
#       dtype=[('TrackId', '<i8'), ('Pos', [('X', '<f8'), ('Y', '<f8'), ('Z', '<f8')]), ('Vel', [('X', '<f8'), ('Y', '<f8'), ('Z', '<f8')]), ('ClassId', '<u4'), ('Status', '<i4')])

# %%
# Show image
a = np.asarray(frame['Image'])
plt.figure(figsize = (12,12))
plt.imshow(a, cmap = 'gist_gray')
plt.plot(640, 570, "og", markersize=10)  # og:shorthand for green circle
plt.show()

# %%
# Add point
detec_points = np.asarray(frame['Detections'])
detec_points

p1 = detec_points[0]
pos = np.array(p1[0].tolist())
exp_pos = np.concatenate([pos, [1]])
cam_pos = exp_pos.dot(world2cam_matrix)
im_pos = cam_pos.dot(proj_matrix)
im_pos
# Out:
# array([ 2.14913152e+03, -3.47957726e+03,  2.60844071e+01,  1.58928154e-11])

# %%
### Visualize Frame

def convert_to_image_space ( coordinates , world2cam , cam2im ):
    """ Input single set of coordinatetes """
    coord_4 = np.ones (4)
    coord_4[0:3] = coordinates
    cams_coord = ( np.matmul( world2cam , coord_4.T )).T
    cams_coord_4 = np.ones(4)
    
    cams_coord_4 [0:3] = cams_coord [0:3]
    ims_coord = ( np . matmul ( cam2im , cams_coord_4 .T )). T
    # Divide by z coordinate for some reason
    ims_coord [0] = ims_coord [0]/ ims_coord [2]
    ims_coord [1] = ims_coord [1]/ ims_coord [2]
    ims_coord = ims_coord [0:2]
    
    return ( ims_coord )


def visualize_frame( camera, frame_idx ):
    """ Input camera file and frame index """
    
    frame = camera['Sequence'][str(frame_idx)]
    detected_points = np.asarray(frame['Detections'])

    x_list = []
    y_list = []

    for point in detected_points:
    
        world_pos = np.array(point[0].tolist())
        fin_pos = convert_to_image_space(world_pos, world2cam_matrix, proj_matrix)
        x_list.append(fin_pos[0])
        y_list.append(fin_pos[1])

    # Show image
    a = np.asarray(frame['Image'])
    plt.figure(figsize = (12,12))
    plt.imshow(a, cmap = 'gist_gray')
    plt.scatter(x_list, y_list, s = 100, color = 'hotpink')
    plt.show()
    detected_points = np.asarray(frame['Detections'])
    
    return

# %%
visualize_frame(f, 567)

# %%
# Show security
a = np.asarray(frame['Security'])
aim = Image.fromarray(a)
aim
# Out:
# <PIL.Image.Image image mode=L size=800x600 at 0x1C6D8DDE280>
